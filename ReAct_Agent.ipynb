# %%
# !pip install langgraph langgraph-prebuilt langgraph-sdk langsmith langchain-community langchain-core langchain-openai notebook tavily-python langchain-google-genai
# Out:
# Requirement already satisfied: langgraph in c:\users\prath\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: langgraph-prebuilt in c:\users\prath\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: langgraph-sdk in c:\users\prath\anaconda3\lib\site-packages (0.1.70)
# Requirement already satisfied: langsmith in c:\users\prath\appdata\roaming\python\python312\site-packages (0.1.147)
# Requirement already satisfied: langchain-community in c:\users\prath\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain-core in c:\users\prath\appdata\roaming\python\python312\site-packages (0.3.62)
# Requirement already satisfied: langchain-openai in c:\users\prath\appdata\roaming\python\python312\site-packages (0.3.13)
# Requirement already satisfied: notebook in c:\users\prath\anaconda3\lib\site-packages (7.2.2)
# Requirement already satisfied: tavily-python in c:\users\prath\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: langchain-google-genai in c:\users\prath\appdata\roaming\python\python312\site-packages (2.1.4)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in c:\users\prath\anaconda3\lib\site-packages (from langgraph) (2.0.26)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langgraph) (2.11.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\prath\anaconda3\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langgraph-sdk) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langgraph-sdk) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langsmith) (2.32.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: anyio in c:\users\prath\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk) (4.9.0)
# Requirement already satisfied: certifi in c:\users\prath\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\prath\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk) (1.0.8)
# Requirement already satisfied: idna in c:\users\prath\appdata\roaming\python\python312\site-packages (from httpx>=0.25.2->langgraph-sdk) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prath\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.4->langgraph) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from pydantic>=2.7.4->langgraph) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langsmith) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langsmith) (2.3.0)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\prath\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\prath\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\prath\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\prath\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\prath\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\prath\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\prath\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\prath\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\prath\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\prath\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\prath\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: greenlet>=1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-openai) (1.74.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\prath\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\prath\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\prath\appdata\roaming\python\python312\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\prath\anaconda3\lib\site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\prath\anaconda3\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\prath\anaconda3\lib\site-packages (from notebook) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\prath\anaconda3\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from notebook) (6.4.2)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.0.4)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (78.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\prath\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in c:\users\prath\appdata\roaming\python\python312\site-packages (from langchain-google-genai) (0.6.18)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.73.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prath\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\prath\appdata\roaming\python\python312\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\prath\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\prath\appdata\roaming\python\python312\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook) (2025.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.0)
# Requirement already satisfied: psutil in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.9.0)
# Requirement already satisfied: decorator in c:\users\prath\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\prath\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.0)
# Requirement already satisfied: colorama in c:\users\prath\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\prath\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\prath\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\prath\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (310)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: uri-template in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in c:\users\prath\anaconda3\lib\site-packages (from langgraph-checkpoint>=2.0.26->langgraph) (1.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\prath\appdata\roaming\python\python312\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\prath\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\prath\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\prath\appdata\roaming\python\python312\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\prath\appdata\roaming\python\python312\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\prath\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\prath\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Requirement already satisfied: executing in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.2)

# %% [markdown]
# - Learn how to create Tools in LangGraph
# - How to create a ReAct Graph
# - Work with different types of Messages such as ToolMessages
# - Test out robustess of our graph

# %%
from typing import Annotated, Sequence, TypedDict #Type annotations for type hints
import os
from dotenv import load_dotenv
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.messages import BaseMessage #The foundational class for all message types in LangGraph
from langchain_core.messages import SystemMessage # Message for providing instructions to the LLM
from langchain_core.messages import ToolMessage #Passes data back to LLM after it calls a tool such as the content and the tool name
from langchain_google_genai import GoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_core.tools import BaseTool
from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from langgraph.graph import StateGraph, END, START
from langgraph.prebuilt import ToolNode

# %% [markdown]
# -annotated is ,, and TypedDict is used for creating dictionaries with specific key-value pairs.

# %% [markdown]
# - **Annotated** - Provides additional context without affecting the type itself, used to add metadata to types
# ```
# from typing import Annotated
#
# def greet(name: Annotated[str, "must be non-empty"]) -> None:
#     print(f"Hello, {name}!")
#
# greet("Pratham")
# ```
#
# - **Sequence** - Used for type hinting sequences, To automatically handle the state updates for sequences such as by adding new message to a chat history
# Sequence is an abstract type that includes any ordered collection that supports:
#
# Indexing (`obj[0]`)
#
# Iteration (`for item in obj`)
#
# Length (`len(obj)`)
#
# So things like:
#
# - list
#
# - tuple
#
# - str
#
# ...all qualify as a Sequence
#
# ```
# from typing import Sequence
#
# def print_items(items: Sequence[str]):
#     for item in items:
#         print(item)
#
# print_items(["apple", "banana", "mango"])  # list
# print_items(("cat", "dog", "fish"))        # tuple
# ```

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Reducer Function
# - Rule that controls how updates from nodes are combined with the existing state
# - Tells us how to merge new data with the existing state
# - without a reducer, updates would have replaced the existing value entirely
#
# ### without a reudcer
#
# ```
# state = {"message": ["hi"]}
# update = {"message": ["hello"]}
# new_state = {"message": ["hello"]}  # This would replace the existing value entirely
# ```
# ### with a reducer
# `
# state = {"message": ["hi"]}
# update = {"message": ["hello"]}
# new_state = {"message": ["hi","hello"]} # This merges the new value with the existing value
# `

# %%
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage],add_messages]

# %%
@tool
def add(a:int, n:int):
    """Adds a number to the current total."""
    return a + n

tools = [add]

model = ChatOpenAI(model = "gpt-4o",openai_api_key = os.environ['OPEN_AI_KEY']).bind_tools(tools)

def model_call(state: AgentState) -> AgentState:
    system_prompt = SystemMessage(
        content="You are a helpful AI assistant. You will answer questions and perform tasks as requested by the user."
    )
    response = model.invoke([system_prompt] + state["messages"])
    return {"messages": state["messages"] + [response]}

# %%
def should_continue(state: AgentState):
    last_message = state["messages"][-1]
    if isinstance(last_message, AIMessage) and last_message.tool_calls:
        return "continue"
    return "end"

# %%
def tool_executor(state: AgentState) -> AgentState:
    last_message = state["messages"][-1]
    new_messages = list(state["messages"])

    if isinstance(last_message, AIMessage) and last_message.tool_calls:
        for call in last_message.tool_calls:
            tool_name = call["name"]
            args = call["args"]
            for tool in tools:
                if tool.name == tool_name:
                    result = tool.invoke(args)
                    new_messages.append(
                        ToolMessage(tool_call_id=call["id"], content=str(result))
                    )
    return {"messages": new_messages}

# %%
graph = StateGraph(AgentState) 
graph.add_node("our_agent",model_call) 

tool_node = ToolNode(tools=tools)
graph.add_node("tool_node", tool_executor)

graph.add_edge(START, "our_agent") #Start the graph with our_agent node

graph.add_conditional_edges(
    "our_agent",
    should_continue,
    {
        "continue":"tool_node",
        "end": END
    }
)

graph.add_edge("tool_node", "our_agent")
graph.add_edge("tool_node", END) #End the graph after tool_node
app = graph.compile()

# %%
def print_stream(stream):
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            print(message.pretty_print())

# %%
inputs = {
    "messages": [
       ("user", "Add 40 + 12 and then multiply the result by 6.Also tell me a joke")
    ]
}
print_stream(app.stream(inputs, stream_mode="values")) #Stream the output of the app with the inputs provided
# Out:
# ('user', 'Add 40 + 12 and then multiply the result by 6.Also tell me a joke')
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_JK2MTR8vtyaZ82QnGt3U4jl5)
#  Call ID: call_JK2MTR8vtyaZ82QnGt3U4jl5
#   Args:
#     a: 40
#     n: 12
# None
# ================================= Tool Message =================================
#
# 52
# None
# ================================== Ai Message ==================================
#
# The result of adding 40 and 12 is 52. Now, I will multiply 52 by 6.
#
# As for the joke:
#
# Why don't scientists trust atoms? Because they make up everything!
#
# Now, let's complete the multiplication task.
# Tool Calls:
#   add (call_xfdOCyjNIahxLLEQldmGU4xG)
#  Call ID: call_xfdOCyjNIahxLLEQldmGU4xG
#   Args:
#     a: 52
#     n: 52
# None
# ================================= Tool Message =================================
#
# 104
# None
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_FKkNcbquHkOhkBVOlkujc5GI)
#  Call ID: call_FKkNcbquHkOhkBVOlkujc5GI
#   Args:
#     a: 104
#     n: 52
# None
# ================================= Tool Message =================================
#
# 156
# None
# ================================== Ai Message ==================================
#
# After multiplying 52 by 6, the final result is 312.
#
# I hope the joke brought a smile to your face!
# None
